# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../../datasets/package.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
sns.scatterplot(data = df , x = 'cgpa' , y = 'package')
plt.title("Scatter plt ")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df[['cgpa']] , df[['package']] , random_state = 42, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

y_pred = lr.predict(x_test)
y_pred = lr.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse * 100}")
# Out:
# Mean Squared Error: 8.417638361329656

# %%
x_train.head()
# Out:
#      cgpa
# 79   7.18
# 197  7.21
# 38   8.62
# 24   6.53
# 122  5.12

# %%
x_train.iloc[0]
# Out:
# cgpa    7.18
# Name: 79, dtype: float64

# %%
y_train.iloc[0]
# Out:
# package    3.0
# Name: 79, dtype: float64

# %%
lr.predict(x_train.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\Sachin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.09615454]])

# %%
plt.plot(x_train , lr.predict(x_train) , color = 'red')
sns.scatterplot(data = df , x = 'cgpa' , y = 'package')
plt.title("Scatter plt ")
plt.show()

# %%
m = lr.coef_
m
# Out:
# array([[0.57425647]])

# %%
b = lr.intercept_
b
# Out:
# array([-1.02700694])

# %%
x_test
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93
# 115  8.35
# 69   7.30
# 170  6.22
# 174  7.32
# 45   7.87
# 66   5.11
# 182  5.88
# 165  8.21
# 78   6.59
# 186  7.84
# 177  7.09
# 56   5.84
# 152  7.37
# 82   5.58
# 68   7.56
# 124  6.06
# 16   6.84
# 148  7.57
# 93   6.79
# 65   7.60
# 60   5.61
# 84   4.26
# 67   6.51
# 125  7.33
# 132  5.84
# 9    8.31
# 18   6.94
# 55   8.20
# 75   6.97
# 150  6.30
# 104  7.62
# 135  6.10
# 137  7.14
# 164  9.06
# 76   6.94
